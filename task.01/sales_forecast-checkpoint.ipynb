# %%
import pandas as pd
df = pd.read_csv("walmart.csv")
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df = df.sort_values('Date')

# %%
df.dtypes
# Out:
# Store                    int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# Holiday_Flag             int64
# Temperature            float64
# Fuel_Price             float64
# CPI                    float64
# Unemployment           float64
# dtype: object

# %%
df['Year'] = df['Date'].dt.year

# %%
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 286       3 2010-02-05     461622.22             0        45.71       2.572
# 2574     19 2010-02-05    1507637.17             0        20.96       2.954
# 2860     21 2010-02-05     798593.88             0        39.05       2.572
# 1001      8 2010-02-05    1004137.09             0        34.14       2.572
# 1716     13 2010-02-05    1967220.53             0        31.53       2.666
#
#              CPI  Unemployment  Year  Month
# 286   214.424881         7.368  2010      2
# 2574  131.527903         8.350  2010      2
# 2860  210.752605         8.324  2010      2
# 1001  214.471451         6.299  2010      2
# 1716  126.442065         8.316  2010      2

# %%
X = df[['Store', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'Year', 'Month']]

# %%
y = df['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
df.head()
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 286       3 2010-02-05     461622.22             0        45.71       2.572
# 2574     19 2010-02-05    1507637.17             0        20.96       2.954
# 2860     21 2010-02-05     798593.88             0        39.05       2.572
# 1001      8 2010-02-05    1004137.09             0        34.14       2.572
# 1716     13 2010-02-05    1967220.53             0        31.53       2.666
#
#              CPI  Unemployment  Year  Month
# 286   214.424881         7.368  2010      2
# 2574  131.527903         8.350  2010      2
# 2860  210.752605         8.324  2010      2
# 1001  214.471451         6.299  2010      2
# 1716  126.442065         8.316  2010      2

# %%
X.head()
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 286       3             0        45.71       2.572  214.424881         7.368
# 2574     19             0        20.96       2.954  131.527903         8.350
# 2860     21             0        39.05       2.572  210.752605         8.324
# 1001      8             0        34.14       2.572  214.471451         6.299
# 1716     13             0        31.53       2.666  126.442065         8.316
#
#       Year  Month
# 286   2010      2
# 2574  2010      2
# 2860  2010      2
# 1001  2010      2
# 1716  2010      2

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 416853.8966068026

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
y_pred = model.predict(X_test)

# %%
rmse = mean_squared_error(y_test, y_pred) ** 0.5

# %%
rmse
# Out:
# 497128.0160202329

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title('Sales Forecast')
plt.show()
